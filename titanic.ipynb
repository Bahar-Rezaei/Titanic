# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
df_test = pd.read_csv("test.csv")
df_train = pd.read_csv("train.csv")

print(df_train.shape)
# Out:
# (891, 12)

# %%
print(df_train.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Pclass_1  Pclass_2  \
# 0  34.5      0      0   330911   7.8292   NaN        Q         0         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0         1
# 3  27.0      0      0   315154   8.6625   NaN        S         0         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0         0
#
#    Pclass_3  Prediction
# 0         1           0
# ...

# %%
# %matplotlib inline
pd.crosstab(df_train.Pclass, df_train.Survived).plot(kind='bar')
plt.title('Does Social Class Affect Survival?')
plt.xlabel('Ticket Class')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %% [markdown]
# ###### predict survived

# %%
#Create dummy variables

df_train_dummies = pd.get_dummies(df_train.Pclass, prefix="Pclass", dtype=int)
df_train = pd.concat([df_train, df_train_dummies], axis=1)
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Pclass_1  Pclass_2  \
# 0      0         A/5 21171   7.2500   NaN        S         0         0
# 1      0          PC 17599  71.2833   C85        C         1         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S         0         0
# ...

# %%
df_test_dummies = pd.get_dummies(df_test.Pclass, prefix="Pclass", dtype=int)
df_test = pd.concat([df_test, df_test_dummies], axis=1)
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Pclass_1  Pclass_2  \
# 0  34.5      0      0   330911   7.8292   NaN        Q         0         0
# 1  47.0      1      0   363272   7.0000   NaN        S         0         0
# 2  62.0      0      0   240276   9.6875   NaN        Q         0         1
# 3  27.0      0      0   315154   8.6625   NaN        S         0         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         0         0
#
#    Pclass_3
# 0         1
# 1         1
# ...

# %%
# Logistic Regression

logreg = LogisticRegression()
result = logreg.fit(df_train[["Pclass_1", "Pclass_2", "Pclass_3"]], df_train["Survived"])
y_pred = logreg.predict(df_test[["Pclass_1", "Pclass_2", "Pclass_3"]])
y_pred = pd.Series(y_pred)
# print(y_pred)

# %%
df_test["Survived"] = y_pred

result = pd.concat([df_test['PassengerId'], df_test["Survived"]], axis=1)
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
result.to_csv("output.csv", index=False)
